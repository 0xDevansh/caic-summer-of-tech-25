# %%
import numpy as np
import matplotlib.pyplot as plt
from LinearRegressor import linearRegression

# %%
X = np.loadtxt('X.npy')
Y = np.loadtxt('Y.npy')

# %%
# visualising no regularisation vs 0.1 L1 reg
w1, l1 = linearRegression(X, Y, 0.1, 0)
w2, l2 = linearRegression(X, Y, 0.1, 1)

np.random.seed(42)
plt.plot(l1[:200], label='l1')
np.random.seed(42)
plt.plot(l2[:200], label='l2')
plt.legend()
